# %%
GROQ_API_KEY="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"

# %%
from groq import Groq

client=Groq(api_key=GROQ_API_KEY)

# %%
pip install agno groq
# Out:
# ...
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached hpack-4.2.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.8 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 4.0 MB/s  0:00:00
# ...
# Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Using cached h2-4.3.0-py3-none-any.whl (61 kB)
# Using cached hpack-4.2.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# ...
#
#    ------ --------------------------------- 1/6 [hpack]
#    ------ --------------------------------- 1/6 [hpack]
# ...
